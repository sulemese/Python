# %% [markdown]
# #SET (KÜME)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Kümeler birden fazla öğeyi tek bir değişkende depolamak için kullanılır.
#
# Set, Python'da veri koleksiyonlarını depolamak için kullanılan 4 yerleşik veri türünden biridir; diğer 3'ü List , Tuple ve Dictionary olup hepsi farklı niteliklere ve kullanıma sahiptir.

# %% [markdown]
# # Set Oluşturma

# %% [markdown]
# ### 1. Yöntem : Köşeli Parantez İle

# %%
thisset = {"apple", "banana", "cherry"}

# %% [markdown]
# ### 2. Yöntem : Yapıcı Metod İle

# %%
thisset = set(("apple", "banana", "cherry"))

# %% [markdown]
# # Set Öğelerinin Özellikleri

# %% [markdown]
# ## 1. Sırasız (Unordered)

# %% [markdown]
# Sırasız, bir setteki öğelerin tanımlanmış bir sıraya sahip olmadığı anlamına gelir.
#
# Ayarlanan öğeler, onları her kullandığınızda farklı bir sırada görünebilir ve indeks veya anahtarla başvurulamaz.

# %% [markdown]
# ## 2.Değiştirilemez (Unchangeable)

# %% [markdown]
# Set öğeleri değiştirilemez; yani set oluşturulduktan sonra öğeleri değiştiremeyiz.
#
# Bir set oluşturulduktan sonra öğelerini değiştiremezsiniz ancak öğeleri kaldırabilir ve yeni öğeler ekleyebilirsiniz.

# %% [markdown]
# ## 3. Kopyalara İzin Vermez (Not Allow Duplicates)

# %% [markdown]
# Kümelerde aynı değere sahip iki öğe bulunamaz.

# %%
#Yinelenen değerler 1 kere tanımlanır.

thisset = {"apple", "banana", "cherry", "apple"}

print(thisset)
# Out:
# {'apple', 'cherry', 'banana'}

# %% [markdown]
# ## 4. Set Öğeleri Herhangi Bir Veri Türünde Olabilir

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {1, 5, 7, 9, 3}
set3 = {True, False, False}

# %% [markdown]
# ## 5. Bir Set Farklı Veri Türlerini Birarada İçerebilir

# %%
#Dizeleri, tamsayıları ve boole değerlerini içeren bir küme:

set1 = {"abc", 34, True, 40, "male"}

# %% [markdown]
# ## 6. True ve 1 değerleri  kümelerde aynı değer olarak kabul edilir ve kopya olarak kabul edilir:

# %%
#True ve 1 kopya değer kabul edildiği için ikisi yerine sadece True yazıldı
thisset = {"apple", "banana", "cherry", True, 1, 2}

print(thisset)
# Out:
# {'cherry', 2, True, 'apple', 'banana'}

# %% [markdown]
# ## 7. False ve 0 değerleri  kümelerde aynı değer olarak kabul edilir ve kopya olarak kabul edilir:

# %%
thisset = {"apple", "banana", "cherry", False, True, 0}

print(thisset)
# Out:
# {False, 'cherry', True, 'apple', 'banana'}

# %% [markdown]
# # Bir Setin Uzunluğu

# %% [markdown]
# Bir setin kaç öğeye sahip olduğunu belirlemek için len() işlevi kullanınç

# %%
thisset = {"apple", "banana", "cherry"}

print(len(thisset))
# Out:
# 3

# %% [markdown]
# # Type()

# %% [markdown]
# Python'un bakış açısına göre kümeler, 'set' veri türüne sahip nesneler olarak tanımlanır:

# %%
myset = {"apple", "banana", "cherry"}
print(type(myset))
# Out:
# <class 'set'>

# %% [markdown]
# # Set Öğelerine Erişim

# %% [markdown]
# Bir dizideki öğelere bir dizine veya anahtara başvurarak erişemezsiniz.
#
# Erişimin 2 yolu vardır:

# %% [markdown]
# ### 1. Yöntem : For Döngüsü İle Set İçinde Dolaşarak

# %%
set1 = {"a","b","c"}
for x in set1:
  print(x)
# Out:
# c
# a
# b

# %% [markdown]
# ### 2. yöntem : "in" Anahtar Kelimesi İle Bir Değerin Varlığını Sorgulatarak

# %%
set1 = {"a","b","c"}
print("a" in set1)
# Out:
# True

# %% [markdown]
# # Set Öğelerini Değiştirme

# %% [markdown]
# Bir set oluşturulduktan sonra öğeleri değiştiremezsiniz ancak yeni öğeler ekleyebilirsiniz.

# %% [markdown]
# # Set'e Öğe Ekleme

# %% [markdown]
# Bir set oluşturulduktan sonra öğeleri değiştiremezsiniz ancak yeni öğeler ekleyebilirsiniz.
#
# Bir kümeye bir öğe eklemek için add() yöntemi kullanın.

# %%
set1 = {"a","b","c"}
set1.add("d")
print(set1)
# Out:
# {'d', 'c', 'a', 'b'}

# %% [markdown]
# Başka bir nesnedeki (list,tuple,dictionary,set) öğeleri geçerli kümeye eklemek için update() yöntemi kullanın.

# %%
set1 = {1,2,3}
set2 = {4,5,6}
set1.update(set2)
print(set1)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
list1=["a","b",1]
set1={1,2,3}
set1.update(list1)
print(set1)
# Out:
# {1, 2, 3, 'a', 'b'}

# %% [markdown]
# # Set Öğesi Kaldırma

# %% [markdown]
# Bir kümedeki bir öğeyi kaldırmak için , remove()veya discard()yöntemini kullanın.

# %% [markdown]
# ### 1. Yöntem : remove() ile

# %% [markdown]
# Not: Kaldırılacak öğe mevcut değilse bir hata ortaya çıkar.

# %%
set1={1,2,3}
set1.remove(1)
print(set1)
# Out:
# {2, 3}

# %%
set1={1,2,3}
set1.remove(4)
print(set1)

# %% [markdown]
# ### 2. Yöntem : discard() ile

# %% [markdown]
# Not: Kaldırılacak öğe mevcut değilse, hata ortaya çıkmaz.

# %%
set1={1,2,3}
set1.discard(4)
print(set1)
# Out:
# {1, 2, 3}

# %% [markdown]
# ### 3. Yöntem : pop() ile

# %% [markdown]
# Rastgele bir öğeyi kaldırır.
#
# Dönüş değeri kaldırılan öğedir.

# %%
set1={1,2,3}
set1.pop()
# Out:
# 1

# %% [markdown]
# ### 4. Yöntem : clear()

# %% [markdown]
# Seti tamamen boşaltır.

# %%
set1={1,2}
set1.clear()
print(set1)
# Out:
# set()

# %% [markdown]
# ### 5. Yöntem : "del" anahtar kelimesi

# %% [markdown]
# Seti tamamen siler.

# %%
set1={1,2}
del set1

# %% [markdown]
# # Set Ve Döngü

# %% [markdown]
# For döngüsü kullanarak set öğelerini dolaşabilirsiniz.

# %%
set1 = {1,2,3,4}
for x in set1:
  print(x)
# Out:
# 1
# 2
# 3
# 4

# %% [markdown]
# # Join Sets

# %% [markdown]
# ### 1. Yöntem : union ile

# %% [markdown]
# Union() Her iki kümedeki tüm öğeleri içeren yeni bir küme döndürür.

# %%
set1 = {"a", "b" , "c"}
set2 = {1, 2, 3}
set3 = set1.union(set2)
print(set3)

# %% [markdown]
# ### 2. Yöntem : update() ile

# %% [markdown]
# Update() bir kümedeki tüm öğeleri diğerine ekler.

# %%
set1 = {"a", "b" , "c"}
set2 = {1, 2, 3}
set3 = set1.update(set2)
print(set3)
# Out:
# None

# %% [markdown]
# # Set Yöntemleri

# %% [markdown]
# #difference()

# %% [markdown]
# İki küme arasındaki farkı içeren bir küme döndürür.

# %% [markdown]
#  ![image.png](data:image/png;base64,...)

# %%
#x de olup y de olmayan öğeleri döndürür.
x={1,2}
y={3,4}
x.difference(y)
# Out:
# {1, 2}

# %%
#y de olup x de olmayan öğeleri döndürür.
x={1,2}
y={3,4}
y.difference(x)
# Out:
# {3, 4}

# %% [markdown]
# #difference_update()

# %% [markdown]
# her iki kümede de ortak olan öğeleri orjinal kümeden kaldırır.
#
# ![image.png](data:image/png;base64,...)

# %%
#x de ve y de ortak olan öğeleri kaldırır.
x={1,2,3}
y={3,4}
x.difference_update(y)
print(x)
# Out:
# {1, 2}

# %% [markdown]
# # intersection()

# %% [markdown]
#  iki veya daha fazla küme arasındaki benzerliği içeren bir küme döndürür.
#
#  ![image.png](data:image/png;base64,...)

# %%
#x de olup y de olmayan öğeleri döndürür.
x={1,2,3}
y={3,4}
x.intersection(y)
# Out:
# {3}

# %%
x = {"a", "b", "c"}
y = {"c", "d", "e"}
z = {"f", "g", "c"}

result = x.intersection(y, z)

print(result)
# Out:
# {'c'}

# %% [markdown]
# #intersection_update()

# %% [markdown]
# 2 kümede ortak olmayanları çıkarır.
#
# ![image.png](data:image/png;base64,...)

# %%
x  = {1,2,3}
y = {1,2,4}
x.intersection_update(y) #3'ü çıkarır
print(x)
y.intersection_update(x) #4'ü çıkarır.
print(y)
# Out:
# {1, 2}
# {1, 2}

# %% [markdown]
# #isdisjoint()

# %% [markdown]
# 2 kümede ortak eleman yoksa True aksi halde False döndürür.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
x={"apple","banana"}
y={"milk","coffe"}
x.isdisjoint(y)
# Out:
# False

# %% [markdown]
# #issubset()

# %% [markdown]
# Bir kümedeki birtakım  öğeler diğer kümeyi oluşturuyorsa bu diğer küme alt kümedir.
#
# ![image.png](data:image/png;base64,...)

# %%
x = {1,2,3}
y={1,2}
y.issubset(x) #y x'in alt kümesi mi ? = True
# Out:
# True

# %%
x = {1,2,3}
y={1,2,4}
y.issubset(x) #y x'in alt kümesi mi ? = True
# Out:
# False

# %% [markdown]
# #issuperset()

# %% [markdown]
# X  seti Y setinin tüm elemanlarını kapsıyorsa X Y'nin üst setidir.
# Örn = x: 1,2,3,4 ve y:1,2
#
# ![image.png](data:image/png;base64,...)

# %%
x = {"f", "e", "d", "c", "b", "a"}
y = {"a", "b", "c"}

z = x.issuperset(y)

print(z)
# Out:
# True

# %% [markdown]
# #symmetric_difference()

# %% [markdown]
# 2 kümede de ortak olmayan elemanların birleşimini döndürür.
#
# ![image.png](data:image/png;base64,...)

# %%
set1={1,2,3,4}
set2={3,4,7}
set1.symmetric_difference(set2)
# Out:
# {1, 2, 7}

# %% [markdown]
# #symmetric_difference_update()

# %% [markdown]
# 2 kümede ortak olan elemanları kaldırır ve diğer elemanları ekler .
#
# ![image.png](data:image/png;base64,...)

# %%
set1  = {1,2,3,4}
set2 = {3,4,7}
set1.symmetric_difference_update(set2)
print(set1)
# Out:
# {1, 2, 7}

# %% [markdown]
# #copy()

# %% [markdown]
# Seti diğer sete kopyalar.

# %%
set1={1,2}
x = set1.copy()
print(x)
# Out:
# {1, 2}
